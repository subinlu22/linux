# %% [markdown]
# <a href="https://colab.research.google.com/github/subinlu22/linux/blob/main/linux_command.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls
# Out:
# sample_data

# %%
# !uname -a
# Out:
# Linux 228fc719f1e1 6.6.113+ #1 SMP Mon Feb  2 12:27:57 UTC 2026 x86_64 x86_64 x86_64 GNU/Linux

# %%
# !cd

# %%
# !pwd
# Out:
# /content
